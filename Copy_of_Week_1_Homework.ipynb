# %% [markdown]
# <a href="https://colab.research.google.com/github/rbutterhof/Week1Homework/blob/main/Copy_of_Week_1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://jlhootman.github.io/harper-nps-posters/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "title": "Atlantic Barrier Islands",
#   "creator": "Harper, Charley",
#   "description": "Poster; 74 x 99 cm",
#   "subject": "United States; National Park Service; Posters; Barrier Islands",
#   "type": "Image;StillImage",
#   "format": "image/png",
#   "language": "eng",
#   "reference_url": "https://jlhootman.github.io/harper-nps-posters/item.html?id=harper04"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://jlhootman.github.io/harper-nps-posters/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "subject",
#       "terms": {
#         "barrier islands": 1,
#         "mount rainier national park": 1,
#         "national park service": 8,
#         "north cascades national park": 1,
#         "olympic national park": 1,
#         "posters": 8,
#         "rocky mountains": 1,
#         "united states": 8
#       }
#     },
#     {
#       "field": "creator",
#       "terms": {
#         "harper, charley": 8
#       }
#     },
#     {
#       "field": "format",
#       "terms": {
#         "image/png": 8
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - Subject
# - Creator
# - Format

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet that shows up the most is National Park Service/United States/posters it is used 8 times on my selected site. Creator=harper, charley and format=image/png also appeared 8 times.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized= pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#                                                title          creator  \
# 0                               The Alpine Northwest  Harper, Charley
# 1                                     Canyon Country  Harper, Charley
# 2                Isle Royale National Park, Michigan  Harper, Charley
# 3                           Atlantic Barrier Islands  Harper, Charley
# 4  The Coral Reef Virgin Islands National Park, B...  Harper, Charley
# 5              Glacier Bay National Monument, Alaska  Harper, Charley
# 6                                The Rocky Mountains  Harper, Charley
# 7                                   The Sierra Range  Harper, Charley
#
#         date          description  \
# 0  1980/1990   Poster; 99 × 74 cm
# 1       1990  Poster; 99 x 74 cm.
# 2       1979  Poster; 74 × 99 cm.
# 3        NaN   Poster; 74 x 99 cm
# 4       1979   Poster; 73 × 99 cm
# 5       1977  Poster; 74 x 99 cm.
# 6       1985   Poster; 74 x 99 cm
# 7  1990/2000  Poster; 100 × 74 cm
#
#                                              subject              type  \
# 0  United States; National Park Service; Posters;...  Image;StillImage
# 1      United States; National Park Service; Posters  Image;StillImage
# 2      United States; National Park Service; Posters  Image;StillImage
# 3  United States; National Park Service; Posters;...  Image;StillImage
# 4      United States; National Park Service; Posters  Image;StillImage
# 5      United States; National Park Service; Posters  Image;StillImage
# 6  United States; National Park Service; Posters;...  Image;StillImage
# 7      United States; National Park Service; Posters  Image;StillImage
#
#       format language                                      reference_url
# 0  image/png      eng  https://jlhootman.github.io/harper-nps-posters...
# 1  image/png      eng  https://jlhootman.github.io/harper-nps-posters...
# 2  image/png      eng  https://jlhootman.github.io/harper-nps-posters...
# 3  image/png      eng  https://jlhootman.github.io/harper-nps-posters...
# 4  image/png      eng  https://jlhootman.github.io/harper-nps-posters...
# 5  image/png      eng  https://jlhootman.github.io/harper-nps-posters...
# 6  image/png      eng  https://jlhootman.github.io/harper-nps-posters...
# 7  image/png      eng  https://jlhootman.github.io/harper-nps-posters...

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(2)
#I shrunk this to 2 as there were only 8 items for this particular site.
# Out:
#                                    title          creator       date  \
# 5  Glacier Bay National Monument, Alaska  Harper, Charley       1977
# 0                   The Alpine Northwest  Harper, Charley  1980/1990
#
#            description                                            subject  \
# 5  Poster; 74 x 99 cm.      United States; National Park Service; Posters
# 0   Poster; 99 × 74 cm  United States; National Park Service; Posters;...
#
#                type     format language  \
# 5  Image;StillImage  image/png      eng
# 0  Image;StillImage  image/png      eng
#
#                                        reference_url
# 5  https://jlhootman.github.io/harper-nps-posters...
# 0  https://jlhootman.github.io/harper-nps-posters...

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
#Full disclosure, I used Gemini to get the str.contains.('Posters').shape[0] part to get around the multiple subject values part. Feel free to not count this for bonus purposes!

# Filter for rows where the subject contains 'Posters' and count them
posters_count = cb_normalized[cb_normalized["subject"].str.contains('Posters')].shape[0]

print(posters_count)
# Out:
# 8

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
